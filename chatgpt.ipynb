# %% [markdown]
# To establish your OpenAI connection, run the first two cells.
# <br>
# To export your chat:
# * use File | Download As and
#   * choose Jupyter Notebook format (.ipynb) or
#   * choose Markdown format (.md) depending on your needs.

# %%
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
	base_url = 'http://aitools.cs.vt.edu:7860/openai/v1',
    api_key="aitools"
)

# %%
def get_completion(prompt, 
				   model="gpt-3.5-turbo", 
				   max_tokens=4000):
	
	messages = [{"role": "user", "content": prompt}]

	response = client.chat.completions.create(
                messages=messages,
                model=model,
                max_tokens=max_tokens,
		        temperature=0)  # this is the degree of randomness of the model's output
	
	return response.choices[0].message.content

def converse(prompt, messages=None, 
			 model="gpt-4-turbo", 
			 max_tokens=4000,
			 temperature=0, 
			 top_p=1, 
			 frequency_penalty=0,
			 presence_penalty=0):
	
    # Add the user's message to the list of messages
    if messages is None:
        messages = []

    messages.append({"role": "user", "content": prompt})

    response = client.chat.completions.create(
                model=model,
		messages=messages,
		temperature=temperature,
		max_tokens=max_tokens,
		top_p=top_p,
		frequency_penalty=frequency_penalty,
		presence_penalty=presence_penalty).choices[0].message.content

    # Add the assistant's message to the list of messages
    messages.append({"role": "assistant", "content": response})

    return response, messages

# %% [markdown]
# ## Example 1: Simple chat
#
# Feel free to remove these cells before you export your chat.

# %%
prompt = f"How are you feeling today?"

# %%
response = get_completion(prompt)
print(response)
# Out:
# I'm just a computer program, so I don't have feelings in the same way that humans do. But I'm here and ready to assist you with anything you need! How can I help you today?

# %% [markdown]
# ## Example 2: Conversation
# Let's maintain a conversation history and see how the model responds to it.
# Feel free to remove these cells before you export your chat.

# %%
messages = []
prompt = f"Hi my name is Jennifer."
response, messages = converse(prompt, messages)
print(f"You: {prompt}\nLLM: {response}")
prompt = f"What is my name?"
response, messages = converse(prompt, messages)
print(f"You: {prompt}\nLLM: {response}")

# %% [markdown]
# ## Example 3: Conversation with GPT-4-Turbo-Preview
#
# Let's make a call using the new model.

# %%
gpt4messages = []
prompt = f"Please compute the area of a circle inside a 345 triangle with one point touching each side of the triangle."
response, gpt4messages = converse(prompt, gpt4messages,
							  model="gpt-4-turbo-preview",					  
							  max_tokens=4000)
print(f"You: {prompt}\nLLM: {response}")
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File d:\Software\python3.8\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File d:\Software\python3.8\lib\site-packages\httpcore\_backends\sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File d:\Software\python3.8\lib\socket.py:807, in create_connection(address, timeout, source_address)
#     806 if err is not None:
# --> 807     raise err
#     808 else:
#
# ...

# %%
messages = []
prompt = f"generate a logo.png for Ducky website which is online AI Q and A service platform"
response, messages = converse(prompt, messages)
print(f"You: {prompt}\nLLM: {response}")
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File d:\Software\python3.8\lib\site-packages\httpcore\_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File d:\Software\python3.8\lib\site-packages\httpcore\_backends\sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File d:\Software\python3.8\lib\socket.py:807, in create_connection(address, timeout, source_address)
#     806 if err is not None:
# --> 807     raise err
#     808 else:
#
# ...
